# %% [markdown]
# ### Tokenization Using NLTK

# %%
import nltk

# %%
corpus = """
Hello, my name is Arnav Saxena. I lift heavy stuff and put them back down. I am improving my focus! That, and I also build cool stuff.
"""

# %% [markdown]
# Convert Sentence into paragraphs
# Sentence --> Paragraphs
#
# sent_tokenize can convert sentences to paragraphs

# %%
from nltk.tokenize import sent_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\arnav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents = sent_tokenize(corpus)

# %% [markdown]
# Tokenizing words
#
# Paragraph ---> Words
# Sentence ---> Words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Arnav',
#  'Saxena',
#  '.',
#  'I',
#  'lift',
#  'heavy',
#  'stuff',
#  'and',
#  'put',
#  'them',
#  'back',
#  'down',
#  '.',
#  'I',
#  'am',
#  'improving',
#  'my',
#  'focus',
#  '!',
#  'That',
#  ',',
#  'and',
#  'I',
#  'also',
#  'build',
#  'cool',
#  'stuff',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'my', 'name', 'is', 'Arnav', 'Saxena', '.']
# ['I', 'lift', 'heavy', 'stuff', 'and', 'put', 'them', 'back', 'down', '.']
# ['I', 'am', 'improving', 'my', 'focus', '!']
# ['That', ',', 'and', 'I', 'also', 'build', 'cool', 'stuff', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Arnav',
#  'Saxena',
#  '.',
#  'I',
#  'lift',
#  'heavy',
#  'stuff',
#  'and',
#  'put',
#  'them',
#  'back',
#  'down',
#  '.',
#  'I',
#  'am',
#  'improving',
#  'my',
#  'focus',
#  '!',
#  'That',
#  ',',
#  'and',
#  'I',
#  'also',
#  'build',
#  'cool',
#  'stuff',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Arnav',
#  'Saxena.',
#  'I',
#  'lift',
#  'heavy',
#  'stuff',
#  'and',
#  'put',
#  'them',
#  'back',
#  'down.',
#  'I',
#  'am',
#  'improving',
#  'my',
#  'focus',
#  '!',
#  'That',
#  ',',
#  'and',
#  'I',
#  'also',
#  'build',
#  'cool',
#  'stuff',
#  '.']

# %%
# Out:
# ['Hello',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Arnav',
#  'Saxena.',
#  'I',
#  'lift',
#  'heavy',
#  'stuff',
#  'and',
#  'put',
#  'them',
#  'back',
#  'down.',
#  'I',
#  'am',
#  'improving',
#  'my',
#  'focus',
#  '!',
#  'That',
#  ',',
#  'and',
#  'I',
#  'also',
#  'build',
#  'cool',
#  'stuff',
#  '.']

# %% [markdown]
# IMDB Dataset of 50K Movie Reviews

# %%
import pandas as pd

# %%
data = "../IMDB Dataset.csv"
df = pd.read_csv(data)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df = df.sample(frac=0.1, random_state=1)
df.shape
# Out:
# (500, 2)

# %% [markdown]
# Converting to lower

# %%
df['review'] = df['review'].str.lower()
df.head()
# Out:
#                                                   review sentiment
# 21842  bela lugosi as creepy insane scientist who use...  negative
# 48842  i should have trusted my instincts better: no ...  negative
# 37824  there is no such a thing as perfect murder.lie...  positive
# 21667  critics claim that this film is one of the wor...  positive
# 49802  the brothers quay are directors, judging by co...  negative

# %% [markdown]
# Removing HTML tags with regular expressions

# %%
import re
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
text  = "<html><head><title>A Title</title></head><body><h1>Header</h1><p>This is a paragraph.</p></body></html>"
remove_html_tags(text)
# Out:
# 'A TitleHeaderThis is a paragraph.'
